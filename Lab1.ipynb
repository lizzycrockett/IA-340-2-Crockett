# %% [markdown]
# # lab1

# %% [markdown]
#  this is my first lab.

# %%
import pandas as pd

covid_data = pd.read_csv( "s3://ia-340-crockett-bucketone561/data.csv" )
covid_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
data_gov = pd.read_csv( "s3://ia-340-crockett-bucketone561/Baton_Rouge_Police_Crime_Incidents.csv" )
data_gov.head()
# Out:
# /tmp/ipykernel_11095/494560279.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_gov = pd.read_csv( "s3://ia-340-crockett-bucketone561/Baton_Rouge_Police_Crime_Incidents.csv" )
#   INCIDENT NUMBER                             CHARGE ID  \
# 0       19-082654  AFF2B61F-AC22-46D5-982D-3CA140D57369
# 1       20-015556  8929E25E-778E-44C0-9387-70ADBD1F02C1
# 2       25-152907                               2797533
# 3       25-500467                               2798913
# 4       25-158798                               2794602
#
#               CHARGE DATE             REPORT DATE           APPROVED DATE  \
# 0  09/08/2019 03:08:00 AM  07/14/2021 01:51:06 PM  07/29/2021 09:00:41 AM
# 1  02/18/2020 02:28:00 PM  02/10/2021 10:05:30 AM  02/10/2021 02:25:17 PM
# 2  05/28/2025 04:10:00 AM  05/28/2025 04:10:25 AM  06/20/2025 03:00:37 AM
# 3  04/21/2025 12:00:00 AM  06/19/2025 09:28:00 AM  06/19/2025 02:19:10 PM
# ...
